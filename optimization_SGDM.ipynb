# %% [markdown]
# <a href="https://colab.research.google.com/github/MaithriRao/Optimization_/blob/main/optimization_SGDM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import torch
import torchvision
from torchvision import datasets,transforms
from torch.utils.data import DataLoader, SubsetRandomSampler
import torch.nn as nn
import torch.nn.functional as F
import numpy as np 
import matplotlib.pyplot as plt 
import torch.optim as optim
from torch.utils.data import random_split

#Check device (cuda or CPU)
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
#transforms 

transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean = [0.4914, 0.4822, 0.4465], std = [0.247, 0.243, 0.261])
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean = [0.4914, 0.4822, 0.4465], std = [0.247, 0.243, 0.261])
])


batch_size = 128

# %%
#Load the dataset 
trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform_train)
testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                        download=True, transform=transform_test)

#split trainset into train and validation 
train_ds, val_ds = random_split(trainset, [int(0.8*len(trainset)), int(00.2*len(trainset))])
print(len(train_ds))
print(len(val_ds))
print(len(testset))

#Dataloaders
train_loader = torch.utils.data.DataLoader(train_ds, batch_size=batch_size,
                                          shuffle=True, num_workers=2, pin_memory = True)
validation_loader = torch.utils.data.DataLoader(val_ds, batch_size=batch_size,
                                          shuffle=True, num_workers=2, pin_memory = True)
test_loader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                          shuffle=True, num_workers=2, pin_memory = True)


#image classes 
num_classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# 40000
# 10000
# 10000

# %%
#ResNet Model
class BasicBlock(nn.Module):
  expansion = 1
  def __init__(self, input_channels, output_channels, stride=1):
    super(BasicBlock, self).__init__()
    self.conv1 = nn.Conv2d(input_channels, output_channels, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(output_channels)
    self.conv2 = nn.Conv2d(output_channels, output_channels, kernel_size=3, stride=1, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(output_channels)

    self.shortcut = nn.Sequential()
    if stride != 1 or input_channels != self.expansion*output_channels:
      self.shortcut = nn.Sequential(
          nn.Conv2d(input_channels, self.expansion*output_channels, kernel_size=1, stride=stride, bias=False),
          nn.BatchNorm2d(self.expansion*output_channels)
      )
  
  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.bn2(self.conv2(out))
    out += self.shortcut(x)
    out = F.relu(out)
    return out

class BottleNeck(nn.Module):
  expansion = 4

  def __init__(self, input_channels, output_channels, stride=1):
    super(BottleNeck, self).__init__()
    self.conv1 = nn.Conv2d(input_channels , output_channels, kernel_size=1, bias=False)
    self.bn1 = nn.BatchNorm2d(output_channels)
    self.conv2 = nn.Conv2d(output_channels, output_channels, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(output_channels)
    self.conv3 = nn.Conv2d(output_channels, self.expansion*output_channels, kernel_size=1, bias=False)
    self.bn3 = nn.BatchNorm2d(self.expansion*output_channels)

    self.shortcut = nn.Sequential()
    if stride != 1 or input_channels != self.expansion*output_channels :
      self.shortcut = nn.Sequential(
          nn.Conv2d(input_channels, self.expansion*output_channels, kernel_size=1, stride=stride, bias=False),
          nn.BatchNorm2d(self.expansion*output_channels)
      )

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = F.relu(self.bn2(self.conv2(out)))
    out = self.bn3(self.conv3(out))
    out += self.shortcut(x)
    out = F.relu(out)
    return out

class ResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(ResNet, self).__init__()
    self.in_planes = 64

    self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(64)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
    self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
    self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
    self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
    self.linear = nn.Linear(512*block.expansion, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1]*(num_blocks-1)
    layers = []
    for stride in strides:
      layers.append(block(self.in_planes, planes, stride))
      self.in_planes = planes * block.expansion      
    return nn.Sequential(*layers)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = F.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

#ResNet18 = ResNet(BasicBlock, [2,2,2,2])
ResNet34 = ResNet(BasicBlock, [3,4,6,3]).to(device)
#ResNet50 = ResNet(BottleNeck, [3,4,6,3])
#ResNet101 = ResNet(BottleNeck, [3,4,23,3])
#ResNet152 = ResNet(BottleNeck, [3,8,36,3])

print(ResNet34)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
#Hyperparameters
batch_size = 128
num_epochs = 200
learning_rate = 0.001
momentum = 0.9

# %%
#loss function 
criterion = nn.CrossEntropyLoss()

#Optimizer
# optimizer = SwatsVanillaGlobal(ResNet34.parameters())
optimizer = optim.SGD(ResNet34.parameters(), lr=0.001, momentum=0.9)

# %%
def model_training(model, train_loader, validation_loader, criterion, optimizer, set_device):
  best_accuracy = 0
  train_loss_history = []
  validation_loss_history = []
  training_acc_history = []
  validation_acc_history = []

  for epoch in range(0, num_epochs):
    model.train()
    train_loss_scores = []
    training_acc_scores = []
    correct_predictions = 0

    for batch_index, (images, targets) in enumerate(train_loader):
      images = images.to(set_device)
      targets = targets.to(set_device)
      
      outputs = model(images)
      loss = criterion(outputs, targets)
      train_loss_scores.append(loss.item())
      
      _, preds = torch.max(outputs, 1)
      correct_predictions = (preds==targets).sum().item()
      training_acc_scores.append(correct_predictions/targets.shape[0])

      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

      if (batch_index+1) % 100 == 0:
        print(f"Epoch : [{epoch+1}/{num_epochs}] | Step : [{batch_index+1}/{len(train_loader)}] | Loss : {loss.item()} ")
            
    train_loss_history.append((sum(train_loss_scores)/len(train_loss_scores)))
    training_acc_history.append((sum(training_acc_scores)/len(training_acc_scores))*100)      
    print(f'Epoch : {epoch+1} | Loss : {train_loss_history[-1]} | Training Accuracy : {training_acc_history[-1]}%')

    model.eval()
    with torch.no_grad():
      correct_predictions = 0
      validation_acc_scores = []
      validation_loss_scores = []

      for images, targets in iter(validation_loader):
        images = images.to(set_device)
        targets = targets.to(set_device)
                    
        outputs = model(images)
        loss = criterion(outputs, targets)
        validation_loss_scores.append(loss.item())

        _, preds = torch.max(outputs, 1)
        correct_predictions = (preds == targets).sum().item()
        validation_acc_scores.append(correct_predictions/targets.shape[0])

      validation_loss_history.append((sum(validation_loss_scores)/len(validation_loss_scores)))
      validation_acc_history.append((sum(validation_acc_scores)/len(validation_acc_scores))*100)
      print(f'Epoch {epoch+1} | Validation Accuracy {validation_acc_history[-1]}%')

      #Early stopping
      if validation_acc_history[-1]>best_accuracy:
        best_accuracy = validation_acc_history[-1]
        print('Saving the model...')
        torch.save(model.state_dict(), f"/content/gdrive/MyDrive/optimization/Accuracy_{best_accuracy}_batchsize_{batch_size}_lr_{learning_rate}.ckpt")

  return train_loss_history, validation_loss_history, training_acc_history, validation_acc_history

# %%
train_loss, validation_loss, train_acc, validation_acc = model_training(ResNet34, train_loader, validation_loader, criterion, optimizer, device)
# Out:
# Epoch : [1/200] | Step : [100/313] | Loss : 1.7864145040512085
# Epoch : [1/200] | Step : [200/313] | Loss : 1.693834900856018
# Epoch : [1/200] | Step : [300/313] | Loss : 1.3545244932174683
# Epoch : 1 | Loss : 1.7226186609877565 | Training Accuracy : 35.600539137380196%
# Epoch 1 | Validation Accuracy 46.5684335443038%
# Saving the model...
# Epoch : [2/200] | Step : [100/313] | Loss : 1.3808088302612305
# Epoch : [2/200] | Step : [200/313] | Loss : 1.1883624792099
# Epoch : [2/200] | Step : [300/313] | Loss : 1.1982426643371582
# Epoch : 2 | Loss : 1.3014202314063001 | Training Accuracy : 52.68320686900958%
# Epoch 2 | Validation Accuracy 55.62697784810127%
# Saving the model...
# Epoch : [3/200] | Step : [100/313] | Loss : 0.976166844367981
# Epoch : [3/200] | Step : [200/313] | Loss : 0.8711411356925964
# Epoch : [3/200] | Step : [300/313] | Loss : 1.0529677867889404
# Epoch : 3 | Loss : 1.076782847936161 | Training Accuracy : 61.36930910543131%
# Epoch 3 | Validation Accuracy 62.5%
# Saving the model...
# Epoch : [4/200] | Step : [100/313] | Loss : 0.9512137770652771
# Epoch : [4/200] | Step : [200/313] | Loss : 0.9124820232391357
# Epoch : [4/200] | Step : [300/313] | Loss : 1.0202027559280396
# Epoch : 4 | Loss : 0.9243521400914786 | Training Accuracy : 66.97034744408946%
# Epoch 4 | Validation Accuracy 67.54351265822784%
# Saving the model...
# Epoch : [5/200] | Step : [100/313] | Loss : 0.8448156714439392
# Epoch : [5/200] | Step : [200/313] | Loss : 0.813742458820343
# Epoch : [5/200] | Step : [300/313] | Loss : 0.8051690459251404
# Epoch : 5 | Loss : 0.8142626715925174 | Training Accuracy : 71.25099840255591%
# Epoch 5 | Validation Accuracy 71.31131329113924%
# Saving the model...
# Epoch : [6/200] | Step : [100/313] | Loss : 0.8517648577690125
# Epoch : [6/200] | Step : [200/313] | Loss : 0.6310499310493469
# Epoch : [6/200] | Step : [300/313] | Loss : 0.5613536238670349
# Epoch : 6 | Loss : 0.7142750161905258 | Training Accuracy : 74.7029752396166%
# Epoch 6 | Validation Accuracy 73.66495253164557%
# Saving the model...
# Epoch : [7/200] | Step : [100/313] | Loss : 0.6556360721588135
# Epoch : [7/200] | Step : [200/313] | Loss : 0.6419065594673157
# Epoch : [7/200] | Step : [300/313] | Loss : 0.6040953397750854
# Epoch : 7 | Loss : 0.6388036227835634 | Training Accuracy : 77.36871006389777%
# Epoch 7 | Validation Accuracy 74.84177215189874%
# Saving the model...
# Epoch : [8/200] | Step : [100/313] | Loss : 0.5327234864234924
# Epoch : [8/200] | Step : [200/313] | Loss : 0.47793981432914734
# Epoch : [8/200] | Step : [300/313] | Loss : 0.5354657769203186
# Epoch : 8 | Loss : 0.5785897886410308 | Training Accuracy : 79.83726038338658%
# Epoch 8 | Validation Accuracy 73.22982594936708%
# Epoch : [9/200] | Step : [100/313] | Loss : 0.628761351108551
# Epoch : [9/200] | Step : [200/313] | Loss : 0.3277190923690796
# Epoch : [9/200] | Step : [300/313] | Loss : 0.3933311998844147
# Epoch : 9 | Loss : 0.5332346928005401 | Training Accuracy : 81.43720047923323%
# Epoch 9 | Validation Accuracy 76.7998417721519%
# Saving the model...
# Epoch : [10/200] | Step : [100/313] | Loss : 0.5307223796844482
# Epoch : [10/200] | Step : [200/313] | Loss : 0.3815757632255554
# Epoch : [10/200] | Step : [300/313] | Loss : 0.5870998501777649
# Epoch : 10 | Loss : 0.491489455437127 | Training Accuracy : 82.77505990415335%
# Epoch 10 | Validation Accuracy 77.76898734177216%
# Saving the model...
# Epoch : [11/200] | Step : [100/313] | Loss : 0.5192676782608032
# Epoch : [11/200] | Step : [200/313] | Loss : 0.47315114736557007
# Epoch : [11/200] | Step : [300/313] | Loss : 0.31727176904678345
# Epoch : 11 | Loss : 0.44984062068378583 | Training Accuracy : 84.12290335463258%
# Epoch 11 | Validation Accuracy 79.62816455696202%
# Saving the model...
# Epoch : [12/200] | Step : [100/313] | Loss : 0.5127384662628174
# Epoch : [12/200] | Step : [200/313] | Loss : 0.4183390140533447
# Epoch : [12/200] | Step : [300/313] | Loss : 0.47542381286621094
# Epoch : 12 | Loss : 0.4258147454299866 | Training Accuracy : 85.05890575079871%
# Epoch 12 | Validation Accuracy 80.56764240506328%
# Saving the model...
# Epoch : [13/200] | Step : [100/313] | Loss : 0.3379899561405182
# Epoch : [13/200] | Step : [200/313] | Loss : 0.3493778109550476
# Epoch : [13/200] | Step : [300/313] | Loss : 0.3220280408859253
# Epoch : 13 | Loss : 0.39047836457578516 | Training Accuracy : 86.33186900958466%
# Epoch 13 | Validation Accuracy 81.40822784810126%
# Saving the model...
# Epoch : [14/200] | Step : [100/313] | Loss : 0.3922251760959625
# Epoch : [14/200] | Step : [200/313] | Loss : 0.38737770915031433
# Epoch : [14/200] | Step : [300/313] | Loss : 0.3683331608772278
# Epoch : 14 | Loss : 0.3694592604812342 | Training Accuracy : 87.07318290734824%
# Epoch 14 | Validation Accuracy 81.6554588607595%
# Saving the model...
# Epoch : [15/200] | Step : [100/313] | Loss : 0.3300415575504303
# Epoch : [15/200] | Step : [200/313] | Loss : 0.3097132444381714
# Epoch : [15/200] | Step : [300/313] | Loss : 0.3736099302768707
# Epoch : 15 | Loss : 0.341285342368455 | Training Accuracy : 88.04662539936102%
# Epoch 15 | Validation Accuracy 81.97191455696202%
# Saving the model...
# Epoch : [16/200] | Step : [100/313] | Loss : 0.3345418870449066
# Epoch : [16/200] | Step : [200/313] | Loss : 0.294514000415802
# Epoch : [16/200] | Step : [300/313] | Loss : 0.32901543378829956
# Epoch : 16 | Loss : 0.32048752970588856 | Training Accuracy : 88.92022763578275%
# Epoch 16 | Validation Accuracy 82.30814873417721%
# Saving the model...
# Epoch : [17/200] | Step : [100/313] | Loss : 0.35678860545158386
# Epoch : [17/200] | Step : [200/313] | Loss : 0.3165304362773895
# Epoch : [17/200] | Step : [300/313] | Loss : 0.2785753607749939
# Epoch : 17 | Loss : 0.3017001971840478 | Training Accuracy : 89.42442092651757%
# Epoch 17 | Validation Accuracy 81.80379746835443%
# Epoch : [18/200] | Step : [100/313] | Loss : 0.3551304042339325
# Epoch : [18/200] | Step : [200/313] | Loss : 0.23656392097473145
# Epoch : [18/200] | Step : [300/313] | Loss : 0.32323959469795227
# Epoch : 18 | Loss : 0.28318802131631504 | Training Accuracy : 90.16323881789138%
# Epoch 18 | Validation Accuracy 82.84216772151899%
# Saving the model...
# Epoch : [19/200] | Step : [100/313] | Loss : 0.2832108736038208
# Epoch : [19/200] | Step : [200/313] | Loss : 0.2550355792045593
# Epoch : [19/200] | Step : [300/313] | Loss : 0.36999309062957764
# Epoch : 19 | Loss : 0.27041256637238087 | Training Accuracy : 90.53763977635782%
# Epoch 19 | Validation Accuracy 84.0684335443038%
# Saving the model...
# Epoch : [20/200] | Step : [100/313] | Loss : 0.22244417667388916
# Epoch : [20/200] | Step : [200/313] | Loss : 0.17003561556339264
# Epoch : [20/200] | Step : [300/313] | Loss : 0.2998558282852173
# Epoch : 20 | Loss : 0.2507913077886874 | Training Accuracy : 91.15914536741214%
# Epoch 20 | Validation Accuracy 83.4256329113924%
# Epoch : [21/200] | Step : [100/313] | Loss : 0.1679028868675232
# Epoch : [21/200] | Step : [200/313] | Loss : 0.190667986869812
# Epoch : [21/200] | Step : [300/313] | Loss : 0.2412867546081543
# Epoch : 21 | Loss : 0.23065720217677352 | Training Accuracy : 91.87300319488818%
# Epoch 21 | Validation Accuracy 83.38607594936708%
# Epoch : [22/200] | Step : [100/313] | Loss : 0.1919635832309723
# Epoch : [22/200] | Step : [200/313] | Loss : 0.2073928266763687
# Epoch : [22/200] | Step : [300/313] | Loss : 0.16183780133724213
# Epoch : 22 | Loss : 0.21601400457727263 | Training Accuracy : 92.35972444089457%
# Epoch 22 | Validation Accuracy 85.30458860759494%
# Saving the model...
# Epoch : [23/200] | Step : [100/313] | Loss : 0.19041244685649872
# Epoch : [23/200] | Step : [200/313] | Loss : 0.23624075949192047
# Epoch : [23/200] | Step : [300/313] | Loss : 0.23503462970256805
# Epoch : 23 | Loss : 0.20763738620014618 | Training Accuracy : 92.63428514376997%
# Epoch 23 | Validation Accuracy 83.19818037974683%
# Epoch : [24/200] | Step : [100/313] | Loss : 0.18447290360927582
# Epoch : [24/200] | Step : [200/313] | Loss : 0.23320411145687103
# Epoch : [24/200] | Step : [300/313] | Loss : 0.16738341748714447
# Epoch : 24 | Loss : 0.2014494547590661 | Training Accuracy : 92.82647763578275%
# Epoch 24 | Validation Accuracy 84.7507911392405%
# Epoch : [25/200] | Step : [100/313] | Loss : 0.18867728114128113
# Epoch : [25/200] | Step : [200/313] | Loss : 0.18095646798610687
# Epoch : [25/200] | Step : [300/313] | Loss : 0.26686567068099976
# Epoch : 25 | Loss : 0.18527120964738508 | Training Accuracy : 93.49041533546327%
# Epoch 25 | Validation Accuracy 84.53322784810126%
# Epoch : [26/200] | Step : [100/313] | Loss : 0.21178072690963745
# Epoch : [26/200] | Step : [200/313] | Loss : 0.164168119430542
# Epoch : [26/200] | Step : [300/313] | Loss : 0.18008282780647278
# Epoch : 26 | Loss : 0.17763979986500436 | Training Accuracy : 93.78993610223642%
# Epoch 26 | Validation Accuracy 85.75949367088607%
# Saving the model...
# Epoch : [27/200] | Step : [100/313] | Loss : 0.16781675815582275
# Epoch : [27/200] | Step : [200/313] | Loss : 0.1496809720993042
# Epoch : [27/200] | Step : [300/313] | Loss : 0.20393939316272736
# Epoch : 27 | Loss : 0.1631128089591718 | Training Accuracy : 94.40145766773162%
# Epoch 27 | Validation Accuracy 84.95846518987342%
# Epoch : [28/200] | Step : [100/313] | Loss : 0.2530197501182556
# Epoch : [28/200] | Step : [200/313] | Loss : 0.11433380842208862
# Epoch : [28/200] | Step : [300/313] | Loss : 0.12602044641971588
# Epoch : 28 | Loss : 0.15648687947481965 | Training Accuracy : 94.40395367412141%
# Epoch 28 | Validation Accuracy 83.46518987341773%
# Epoch : [29/200] | Step : [100/313] | Loss : 0.12128312885761261
# Epoch : [29/200] | Step : [200/313] | Loss : 0.1045079231262207
# Epoch : [29/200] | Step : [300/313] | Loss : 0.14738714694976807
# Epoch : 29 | Loss : 0.13954229014940536 | Training Accuracy : 95.01297923322683%
# Epoch 29 | Validation Accuracy 85.35403481012658%
# Epoch : [30/200] | Step : [100/313] | Loss : 0.10849480330944061
# Epoch : [30/200] | Step : [200/313] | Loss : 0.14234009385108948
# Epoch : [30/200] | Step : [300/313] | Loss : 0.14654360711574554
# Epoch : 30 | Loss : 0.14658064207139487 | Training Accuracy : 94.86321884984025%
# Epoch 30 | Validation Accuracy 85.79905063291139%
# Saving the model...
# Epoch : [31/200] | Step : [100/313] | Loss : 0.18077924847602844
# Epoch : [31/200] | Step : [200/313] | Loss : 0.1176934689283371
# Epoch : [31/200] | Step : [300/313] | Loss : 0.10647538304328918
# Epoch : 31 | Loss : 0.12856670965949377 | Training Accuracy : 95.49470846645367%
# Epoch 31 | Validation Accuracy 85.73971518987342%
# Epoch : [32/200] | Step : [100/313] | Loss : 0.17468219995498657
# Epoch : [32/200] | Step : [200/313] | Loss : 0.08332864940166473
# Epoch : [32/200] | Step : [300/313] | Loss : 0.05142369866371155
# Epoch : 32 | Loss : 0.1294728696655732 | Training Accuracy : 95.3025159744409%
# Epoch 32 | Validation Accuracy 85.62104430379746%
# Epoch : [33/200] | Step : [100/313] | Loss : 0.06535167247056961
# Epoch : [33/200] | Step : [200/313] | Loss : 0.1427450031042099
# Epoch : [33/200] | Step : [300/313] | Loss : 0.06461024284362793
# Epoch : 33 | Loss : 0.11393412250204209 | Training Accuracy : 95.93650159744409%
# Epoch 33 | Validation Accuracy 85.90783227848101%
# Saving the model...
# Epoch : [34/200] | Step : [100/313] | Loss : 0.08042841404676437
# Epoch : [34/200] | Step : [200/313] | Loss : 0.09531795978546143
# Epoch : [34/200] | Step : [300/313] | Loss : 0.15561625361442566
# Epoch : 34 | Loss : 0.11280760277336398 | Training Accuracy : 95.92402156549521%
# Epoch 34 | Validation Accuracy 85.8682753164557%
# Epoch : [35/200] | Step : [100/313] | Loss : 0.0861089751124382
# Epoch : [35/200] | Step : [200/313] | Loss : 0.13101308047771454
# Epoch : [35/200] | Step : [300/313] | Loss : 0.044354282319545746
# Epoch : 35 | Loss : 0.10551371322438931 | Training Accuracy : 96.23352635782749%
# Epoch 35 | Validation Accuracy 86.52096518987342%
# Saving the model...
# Epoch : [36/200] | Step : [100/313] | Loss : 0.041143760085105896
# Epoch : [36/200] | Step : [200/313] | Loss : 0.03228269889950752
# Epoch : [36/200] | Step : [300/313] | Loss : 0.09262549132108688
# Epoch : 36 | Loss : 0.0986954620042548 | Training Accuracy : 96.55800718849841%
# Epoch 36 | Validation Accuracy 85.97705696202532%
# Epoch : [37/200] | Step : [100/313] | Loss : 0.14045709371566772
# Epoch : [37/200] | Step : [200/313] | Loss : 0.05336074158549309
# Epoch : [37/200] | Step : [300/313] | Loss : 0.07559026032686234
# Epoch : 37 | Loss : 0.09139986149966717 | Training Accuracy : 96.75269568690096%
# Epoch 37 | Validation Accuracy 86.16495253164557%
# Epoch : [38/200] | Step : [100/313] | Loss : 0.10387877374887466
# Epoch : [38/200] | Step : [200/313] | Loss : 0.05750177055597305
# Epoch : [38/200] | Step : [300/313] | Loss : 0.10717800259590149
# Epoch : 38 | Loss : 0.08960534111498453 | Training Accuracy : 96.8001198083067%
# Epoch 38 | Validation Accuracy 85.41337025316456%
# Epoch : [39/200] | Step : [100/313] | Loss : 0.13200010359287262
# Epoch : [39/200] | Step : [200/313] | Loss : 0.12362498790025711
# Epoch : [39/200] | Step : [300/313] | Loss : 0.049876756966114044
# Epoch : 39 | Loss : 0.0787205718541012 | Training Accuracy : 97.23692092651757%
# Epoch 39 | Validation Accuracy 86.47151898734177%
# Epoch : [40/200] | Step : [100/313] | Loss : 0.03267401456832886
# Epoch : [40/200] | Step : [200/313] | Loss : 0.09259635955095291
# Epoch : [40/200] | Step : [300/313] | Loss : 0.10376790165901184
# Epoch : 40 | Loss : 0.08216303173964397 | Training Accuracy : 97.11212060702876%
# Epoch 40 | Validation Accuracy 86.46162974683544%
# Epoch : [41/200] | Step : [100/313] | Loss : 0.12580235302448273
# Epoch : [41/200] | Step : [200/313] | Loss : 0.08570275455713272
# Epoch : [41/200] | Step : [300/313] | Loss : 0.06905657052993774
# Epoch : 41 | Loss : 0.07745299338937377 | Training Accuracy : 97.21944888178913%
# Epoch 41 | Validation Accuracy 86.84731012658227%
# Saving the model...
# Epoch : [42/200] | Step : [100/313] | Loss : 0.09436718374490738
# Epoch : [42/200] | Step : [200/313] | Loss : 0.08244755864143372
# Epoch : [42/200] | Step : [300/313] | Loss : 0.06666748970746994
# Epoch : 42 | Loss : 0.0741107137174533 | Training Accuracy : 97.3592252396166%
# Epoch 42 | Validation Accuracy 87.1242088607595%
# Saving the model...
# Epoch : [43/200] | Step : [100/313] | Loss : 0.07094212621450424
# Epoch : [43/200] | Step : [200/313] | Loss : 0.05451710522174835
# Epoch : [43/200] | Step : [300/313] | Loss : 0.07310300320386887
# Epoch : 43 | Loss : 0.06743619092011129 | Training Accuracy : 97.6462659744409%
# Epoch 43 | Validation Accuracy 85.12658227848101%
# Epoch : [44/200] | Step : [100/313] | Loss : 0.08104056119918823
# Epoch : [44/200] | Step : [200/313] | Loss : 0.09519263356924057
# Epoch : [44/200] | Step : [300/313] | Loss : 0.10029390454292297
# Epoch : 44 | Loss : 0.0630037637022785 | Training Accuracy : 97.8359624600639%
# Epoch 44 | Validation Accuracy 87.65822784810126%
# Saving the model...
# Epoch : [45/200] | Step : [100/313] | Loss : 0.18959715962409973
# Epoch : [45/200] | Step : [200/313] | Loss : 0.0951385572552681
# Epoch : [45/200] | Step : [300/313] | Loss : 0.06800072640180588
# Epoch : 45 | Loss : 0.06696548565222432 | Training Accuracy : 97.63378594249201%
# Epoch 45 | Validation Accuracy 86.85719936708861%
# Epoch : [46/200] | Step : [100/313] | Loss : 0.0392104908823967
# Epoch : [46/200] | Step : [200/313] | Loss : 0.06177056208252907
# Epoch : [46/200] | Step : [300/313] | Loss : 0.04204549267888069
# Epoch : 46 | Loss : 0.06153083230538395 | Training Accuracy : 97.80850638977637%
# Epoch 46 | Validation Accuracy 86.21439873417721%
# Epoch : [47/200] | Step : [100/313] | Loss : 0.0709080621600151
# Epoch : [47/200] | Step : [200/313] | Loss : 0.06413453817367554
# Epoch : [47/200] | Step : [300/313] | Loss : 0.0519912987947464
# Epoch : 47 | Loss : 0.05581859375138919 | Training Accuracy : 98.00319488817891%
# Epoch 47 | Validation Accuracy 86.84731012658227%
# Epoch : [48/200] | Step : [100/313] | Loss : 0.031212715432047844
# Epoch : [48/200] | Step : [200/313] | Loss : 0.08031530678272247
# Epoch : [48/200] | Step : [300/313] | Loss : 0.045574210584163666
# Epoch : 48 | Loss : 0.0566409416050433 | Training Accuracy : 98.09804313099042%
# Epoch 48 | Validation Accuracy 87.08465189873418%
# Epoch : [49/200] | Step : [100/313] | Loss : 0.09406860172748566
# Epoch : [49/200] | Step : [200/313] | Loss : 0.09120497107505798
# Epoch : [49/200] | Step : [300/313] | Loss : 0.049479931592941284
# Epoch : 49 | Loss : 0.05247825174964369 | Training Accuracy : 98.15045926517571%
# Epoch 49 | Validation Accuracy 87.24287974683544%
# Epoch : [50/200] | Step : [100/313] | Loss : 0.03136136755347252
# Epoch : [50/200] | Step : [200/313] | Loss : 0.07458172738552094
# Epoch : [50/200] | Step : [300/313] | Loss : 0.0998208150267601
# Epoch : 50 | Loss : 0.05223888082626148 | Training Accuracy : 98.17042731629392%
# Epoch 50 | Validation Accuracy 87.59889240506328%
# Epoch : [51/200] | Step : [100/313] | Loss : 0.029166720807552338
# Epoch : [51/200] | Step : [200/313] | Loss : 0.056139033287763596
# Epoch : [51/200] | Step : [300/313] | Loss : 0.03460013121366501
# Epoch : 51 | Loss : 0.04995525551412385 | Training Accuracy : 98.18789936102237%
# Epoch 51 | Validation Accuracy 87.57911392405063%
# Epoch : [52/200] | Step : [100/313] | Loss : 0.04472677782177925
# Epoch : [52/200] | Step : [200/313] | Loss : 0.04713252931833267
# Epoch : [52/200] | Step : [300/313] | Loss : 0.04771776124835014
# Epoch : 52 | Loss : 0.04695739206551506 | Training Accuracy : 98.37010782747603%
# Epoch 52 | Validation Accuracy 87.23299050632912%
# Epoch : [53/200] | Step : [100/313] | Loss : 0.039728377014398575
# Epoch : [53/200] | Step : [200/313] | Loss : 0.03659007325768471
# Epoch : [53/200] | Step : [300/313] | Loss : 0.03292086347937584
# Epoch : 53 | Loss : 0.04282807032116495 | Training Accuracy : 98.49740415335462%
# Epoch 53 | Validation Accuracy 87.83623417721519%
# Saving the model...
# Epoch : [54/200] | Step : [100/313] | Loss : 0.02965839020907879
# Epoch : [54/200] | Step : [200/313] | Loss : 0.041086602956056595
# Epoch : [54/200] | Step : [300/313] | Loss : 0.04087398201227188
# Epoch : 54 | Loss : 0.042895074648122054 | Training Accuracy : 98.5323482428115%
# Epoch 54 | Validation Accuracy 87.29232594936708%
# Epoch : [55/200] | Step : [100/313] | Loss : 0.04993947222828865
# Epoch : [55/200] | Step : [200/313] | Loss : 0.02465718612074852
# Epoch : [55/200] | Step : [300/313] | Loss : 0.034032005816698074
# Epoch : 55 | Loss : 0.04128192269880051 | Training Accuracy : 98.627196485623%
# Epoch 55 | Validation Accuracy 87.83623417721519%
# Epoch : [56/200] | Step : [100/313] | Loss : 0.03220188245177269
# Epoch : [56/200] | Step : [200/313] | Loss : 0.0346047468483448
# Epoch : [56/200] | Step : [300/313] | Loss : 0.023219803348183632
# Epoch : 56 | Loss : 0.03699831590324212 | Training Accuracy : 98.6596445686901%
# Epoch 56 | Validation Accuracy 87.88568037974683%
# Saving the model...
# Epoch : [57/200] | Step : [100/313] | Loss : 0.020863372832536697
# Epoch : [57/200] | Step : [200/313] | Loss : 0.009593718685209751
# Epoch : [57/200] | Step : [300/313] | Loss : 0.01010994054377079
# Epoch : 57 | Loss : 0.035890022300171874 | Training Accuracy : 98.73702076677317%
# Epoch 57 | Validation Accuracy 87.39121835443038%
# Epoch : [58/200] | Step : [100/313] | Loss : 0.031189920380711555
# Epoch : [58/200] | Step : [200/313] | Loss : 0.0069212415255606174
# Epoch : [58/200] | Step : [300/313] | Loss : 0.043672822415828705
# Epoch : 58 | Loss : 0.03719173412555799 | Training Accuracy : 98.66214057507987%
# Epoch 58 | Validation Accuracy 87.9054588607595%
# Saving the model...
# Epoch : [59/200] | Step : [100/313] | Loss : 0.03394080698490143
# Epoch : [59/200] | Step : [200/313] | Loss : 0.017377818003296852
# Epoch : [59/200] | Step : [300/313] | Loss : 0.03210464492440224
# Epoch : 59 | Loss : 0.03870857752392443 | Training Accuracy : 98.59724440894568%
# Epoch 59 | Validation Accuracy 87.82634493670885%
# Epoch : [60/200] | Step : [100/313] | Loss : 0.013255502097308636
# Epoch : [60/200] | Step : [200/313] | Loss : 0.011543584056198597
# Epoch : [60/200] | Step : [300/313] | Loss : 0.01003718189895153
# Epoch : 60 | Loss : 0.03463532389944997 | Training Accuracy : 98.76198083067092%
# Epoch 60 | Validation Accuracy 87.83623417721519%
# Epoch : [61/200] | Step : [100/313] | Loss : 0.030816640704870224
# Epoch : [61/200] | Step : [200/313] | Loss : 0.009884705767035484
# Epoch : [61/200] | Step : [300/313] | Loss : 0.05534137040376663
# Epoch : 61 | Loss : 0.03639910578022536 | Training Accuracy : 98.74700479233228%
# Epoch 61 | Validation Accuracy 87.63844936708861%
# Epoch : [62/200] | Step : [100/313] | Loss : 0.022520799189805984
# Epoch : [62/200] | Step : [200/313] | Loss : 0.018148208037018776
# Epoch : [62/200] | Step : [300/313] | Loss : 0.031599756330251694
# Epoch : 62 | Loss : 0.03195993702586431 | Training Accuracy : 98.89426916932908%
# Epoch 62 | Validation Accuracy 87.85601265822784%
# Epoch : [63/200] | Step : [100/313] | Loss : 0.00877640675753355
# Epoch : [63/200] | Step : [200/313] | Loss : 0.053706083446741104
# Epoch : [63/200] | Step : [300/313] | Loss : 0.02707044407725334
# Epoch : 63 | Loss : 0.03567821898098928 | Training Accuracy : 98.71705271565496%
# Epoch 63 | Validation Accuracy 87.98457278481013%
# Saving the model...
# Epoch : [64/200] | Step : [100/313] | Loss : 0.0395490899682045
# Epoch : [64/200] | Step : [200/313] | Loss : 0.025018779560923576
# Epoch : [64/200] | Step : [300/313] | Loss : 0.04361291974782944
# Epoch : 64 | Loss : 0.027922187382861164 | Training Accuracy : 99.06150159744409%
# Epoch 64 | Validation Accuracy 88.10324367088607%
# Saving the model...
# Epoch : [65/200] | Step : [100/313] | Loss : 0.05437565594911575
# Epoch : [65/200] | Step : [200/313] | Loss : 0.02655094675719738
# Epoch : [65/200] | Step : [300/313] | Loss : 0.010072804987430573
# Epoch : 65 | Loss : 0.029079968322473115 | Training Accuracy : 99.05650958466452%
# Epoch 65 | Validation Accuracy 88.24169303797468%
# Saving the model...
# Epoch : [66/200] | Step : [100/313] | Loss : 0.019301192834973335
# Epoch : [66/200] | Step : [200/313] | Loss : 0.011945853941142559
# Epoch : [66/200] | Step : [300/313] | Loss : 0.022199556231498718
# Epoch : 66 | Loss : 0.031283819500487836 | Training Accuracy : 98.9541733226837%
# Epoch 66 | Validation Accuracy 87.16376582278481%
# Epoch : [67/200] | Step : [100/313] | Loss : 0.010847963392734528
# Epoch : [67/200] | Step : [200/313] | Loss : 0.01110457070171833
# Epoch : [67/200] | Step : [300/313] | Loss : 0.022907305508852005
# Epoch : 67 | Loss : 0.022802671831556428 | Training Accuracy : 99.23372603833866%
# Epoch 67 | Validation Accuracy 88.15268987341773%
# Epoch : [68/200] | Step : [100/313] | Loss : 0.012810146436095238
# Epoch : [68/200] | Step : [200/313] | Loss : 0.027818651869893074
# Epoch : [68/200] | Step : [300/313] | Loss : 0.02254587598145008
# Epoch : 68 | Loss : 0.029029025586125568 | Training Accuracy : 98.93919728434504%
# Epoch 68 | Validation Accuracy 88.15268987341773%
# Epoch : [69/200] | Step : [100/313] | Loss : 0.006641327869147062
# Epoch : [69/200] | Step : [200/313] | Loss : 0.031345807015895844
# Epoch : [69/200] | Step : [300/313] | Loss : 0.016670027747750282
# Epoch : 69 | Loss : 0.025205451049306354 | Training Accuracy : 99.1438698083067%
# Epoch 69 | Validation Accuracy 88.12302215189874%
# Epoch : [70/200] | Step : [100/313] | Loss : 0.006084590684622526
# Epoch : [70/200] | Step : [200/313] | Loss : 0.04521503299474716
# Epoch : [70/200] | Step : [300/313] | Loss : 0.01918686181306839
# Epoch : 70 | Loss : 0.02430865673397403 | Training Accuracy : 99.15884584664538%
# Epoch 70 | Validation Accuracy 88.37025316455697%
# Saving the model...
# Epoch : [71/200] | Step : [100/313] | Loss : 0.023102380335330963
# Epoch : [71/200] | Step : [200/313] | Loss : 0.00681897671893239
# Epoch : [71/200] | Step : [300/313] | Loss : 0.056542690843343735
# Epoch : 71 | Loss : 0.02345966005671067 | Training Accuracy : 99.19378993610223%
# Epoch 71 | Validation Accuracy 87.96479430379746%
# Epoch : [72/200] | Step : [100/313] | Loss : 0.04598121717572212
# Epoch : [72/200] | Step : [200/313] | Loss : 0.034969329833984375
# Epoch : [72/200] | Step : [300/313] | Loss : 0.0042992690578103065
# Epoch : 72 | Loss : 0.026513031343170724 | Training Accuracy : 99.13887779552716%
# Epoch 72 | Validation Accuracy 88.76582278481013%
# Saving the model...
# Epoch : [73/200] | Step : [100/313] | Loss : 0.048376135528087616
# Epoch : [73/200] | Step : [200/313] | Loss : 0.034834906458854675
# Epoch : [73/200] | Step : [300/313] | Loss : 0.010250397026538849
# Epoch : 73 | Loss : 0.02474876658242648 | Training Accuracy : 99.15385383386581%
# Epoch 73 | Validation Accuracy 87.93512658227847%
# Epoch : [74/200] | Step : [100/313] | Loss : 0.017853058874607086
# Epoch : [74/200] | Step : [200/313] | Loss : 0.023143386468291283
# Epoch : [74/200] | Step : [300/313] | Loss : 0.024403223767876625
# Epoch : 74 | Loss : 0.01994409360298024 | Training Accuracy : 99.2936301916933%
# Epoch 74 | Validation Accuracy 87.9054588607595%
# Epoch : [75/200] | Step : [100/313] | Loss : 0.006836075335741043
# Epoch : [75/200] | Step : [200/313] | Loss : 0.01486283726990223
# Epoch : [75/200] | Step : [300/313] | Loss : 0.009741637855768204
# Epoch : 75 | Loss : 0.022803596444442846 | Training Accuracy : 99.24371006389777%
# Epoch 75 | Validation Accuracy 87.9054588607595%
# Epoch : [76/200] | Step : [100/313] | Loss : 0.004683330655097961
# Epoch : [76/200] | Step : [200/313] | Loss : 0.04145682603120804
# Epoch : [76/200] | Step : [300/313] | Loss : 0.011502676643431187
# Epoch : 76 | Loss : 0.022161813329357783 | Training Accuracy : 99.21126198083067%
# Epoch 76 | Validation Accuracy 88.28125%
# Epoch : [77/200] | Step : [100/313] | Loss : 0.01206029299646616
# Epoch : [77/200] | Step : [200/313] | Loss : 0.04205984249711037
# Epoch : [77/200] | Step : [300/313] | Loss : 0.027446666732430458
# Epoch : 77 | Loss : 0.02027756958261144 | Training Accuracy : 99.36102236421725%
# Epoch 77 | Validation Accuracy 87.79667721518987%
# Epoch : [78/200] | Step : [100/313] | Loss : 0.014434142038226128
# Epoch : [78/200] | Step : [200/313] | Loss : 0.00826803408563137
# Epoch : [78/200] | Step : [300/313] | Loss : 0.02234521694481373
# Epoch : 78 | Loss : 0.01893712422280861 | Training Accuracy : 99.35852635782749%
# Epoch 78 | Validation Accuracy 88.33069620253164%
# Epoch : [79/200] | Step : [100/313] | Loss : 0.0361945740878582
# Epoch : [79/200] | Step : [200/313] | Loss : 0.0147250946611166
# Epoch : [79/200] | Step : [300/313] | Loss : 0.027456820011138916
# Epoch : 79 | Loss : 0.01701151860465769 | Training Accuracy : 99.45337460063898%
# Epoch 79 | Validation Accuracy 88.76582278481013%
# Epoch : [80/200] | Step : [100/313] | Loss : 0.0028926008380949497
# Epoch : [80/200] | Step : [200/313] | Loss : 0.00839095190167427
# Epoch : [80/200] | Step : [300/313] | Loss : 0.004530697129666805
# Epoch : 80 | Loss : 0.014481021946232124 | Training Accuracy : 99.5157747603834%
# Epoch 80 | Validation Accuracy 88.53837025316456%
# Epoch : [81/200] | Step : [100/313] | Loss : 0.02309349924325943
# Epoch : [81/200] | Step : [200/313] | Loss : 0.029361560940742493
# Epoch : [81/200] | Step : [300/313] | Loss : 0.024941125884652138
# Epoch : 81 | Loss : 0.019918850556866954 | Training Accuracy : 99.32857428115017%
# Epoch 81 | Validation Accuracy 88.73615506329115%
# Epoch : [82/200] | Step : [100/313] | Loss : 0.023663656786084175
# Epoch : [82/200] | Step : [200/313] | Loss : 0.006893055979162455
# Epoch : [82/200] | Step : [300/313] | Loss : 0.024228466674685478
# Epoch : 82 | Loss : 0.021443408740217242 | Training Accuracy : 99.2611821086262%
# Epoch 82 | Validation Accuracy 88.57792721518987%
# Epoch : [83/200] | Step : [100/313] | Loss : 0.043279100209474564
# Epoch : [83/200] | Step : [200/313] | Loss : 0.0030483922455459833
# Epoch : [83/200] | Step : [300/313] | Loss : 0.02798832394182682
# Epoch : 83 | Loss : 0.01665193930362387 | Training Accuracy : 99.4508785942492%
# Epoch 83 | Validation Accuracy 88.20213607594937%
# Epoch : [84/200] | Step : [100/313] | Loss : 0.00851014256477356
# Epoch : [84/200] | Step : [200/313] | Loss : 0.011116175912320614
# Epoch : [84/200] | Step : [300/313] | Loss : 0.037764713168144226
# Epoch : 84 | Loss : 0.017987600495717442 | Training Accuracy : 99.42841453674122%
# Epoch 84 | Validation Accuracy 87.99446202531645%
# Epoch : [85/200] | Step : [100/313] | Loss : 0.008085578680038452
# Epoch : [85/200] | Step : [200/313] | Loss : 0.005459687672555447
# Epoch : [85/200] | Step : [300/313] | Loss : 0.006819846108555794
# Epoch : 85 | Loss : 0.01799572226029788 | Training Accuracy : 99.42342252396166%
# Epoch 85 | Validation Accuracy 88.61748417721519%
# Epoch : [86/200] | Step : [100/313] | Loss : 0.012051512487232685
# Epoch : [86/200] | Step : [200/313] | Loss : 0.005736557766795158
# Epoch : [86/200] | Step : [300/313] | Loss : 0.013062125071883202
# Epoch : 86 | Loss : 0.01578206915914947 | Training Accuracy : 99.4833266773163%
# Epoch 86 | Validation Accuracy 88.96360759493672%
# Saving the model...
# Epoch : [87/200] | Step : [100/313] | Loss : 0.005168674048036337
# Epoch : [87/200] | Step : [200/313] | Loss : 0.004201038274914026
# Epoch : [87/200] | Step : [300/313] | Loss : 0.011061935685575008
# Epoch : 87 | Loss : 0.013960740175291586 | Training Accuracy : 99.5157747603834%
# Epoch 87 | Validation Accuracy 87.98457278481013%
# Epoch : [88/200] | Step : [100/313] | Loss : 0.05641927942633629
# Epoch : [88/200] | Step : [200/313] | Loss : 0.022876596078276634
# Epoch : [88/200] | Step : [300/313] | Loss : 0.0016497590113431215
# Epoch : 88 | Loss : 0.01674952746157686 | Training Accuracy : 99.43839856230032%
# Epoch 88 | Validation Accuracy 88.95371835443038%
# Epoch : [89/200] | Step : [100/313] | Loss : 0.02178468368947506
# Epoch : [89/200] | Step : [200/313] | Loss : 0.0060228509828448296
# Epoch : [89/200] | Step : [300/313] | Loss : 0.040093015879392624
# Epoch : 89 | Loss : 0.014823426003791034 | Training Accuracy : 99.5257587859425%
# Epoch 89 | Validation Accuracy 88.67681962025317%
# Epoch : [90/200] | Step : [100/313] | Loss : 0.003379943547770381
# Epoch : [90/200] | Step : [200/313] | Loss : 0.06943540275096893
# Epoch : [90/200] | Step : [300/313] | Loss : 0.01118852011859417
# Epoch : 90 | Loss : 0.015528505368730256 | Training Accuracy : 99.44838258785943%
# Epoch 90 | Validation Accuracy 88.77571202531645%
# Epoch : [91/200] | Step : [100/313] | Loss : 0.004488557577133179
# Epoch : [91/200] | Step : [200/313] | Loss : 0.01576741226017475
# Epoch : [91/200] | Step : [300/313] | Loss : 0.008160621859133244
# Epoch : 91 | Loss : 0.013738251021842268 | Training Accuracy : 99.54073482428115%
# Epoch 91 | Validation Accuracy 88.61748417721519%
# Epoch : [92/200] | Step : [100/313] | Loss : 0.0037711244076490402
# Epoch : [92/200] | Step : [200/313] | Loss : 0.0031730537302792072
# Epoch : [92/200] | Step : [300/313] | Loss : 0.007554537616670132
# Epoch : 92 | Loss : 0.013965350363556795 | Training Accuracy : 99.52076677316293%
# Epoch 92 | Validation Accuracy 88.50870253164557%
# Epoch : [93/200] | Step : [100/313] | Loss : 0.0020336259622126818
# Epoch : [93/200] | Step : [200/313] | Loss : 0.002687714993953705
# Epoch : [93/200] | Step : [300/313] | Loss : 0.01860940456390381
# Epoch : 93 | Loss : 0.011869732079712805 | Training Accuracy : 99.60812699680511%
# Epoch 93 | Validation Accuracy 88.24169303797468%
# Epoch : [94/200] | Step : [100/313] | Loss : 0.003033993998542428
# Epoch : [94/200] | Step : [200/313] | Loss : 0.005054127890616655
# Epoch : [94/200] | Step : [300/313] | Loss : 0.005600417964160442
# Epoch : 94 | Loss : 0.011713281080157262 | Training Accuracy : 99.64806309904152%
# Epoch 94 | Validation Accuracy 88.76582278481013%
# Epoch : [95/200] | Step : [100/313] | Loss : 0.001661305082961917
# Epoch : [95/200] | Step : [200/313] | Loss : 0.015449145808815956
# Epoch : [95/200] | Step : [300/313] | Loss : 0.0033298868220299482
# Epoch : 95 | Loss : 0.011686644237237453 | Training Accuracy : 99.58316693290735%
# Epoch 95 | Validation Accuracy 89.07238924050634%
# Saving the model...
# Epoch : [96/200] | Step : [100/313] | Loss : 0.002035742159932852
# Epoch : [96/200] | Step : [200/313] | Loss : 0.0070356763899326324
# Epoch : [96/200] | Step : [300/313] | Loss : 0.006920056417584419
# Epoch : 96 | Loss : 0.010868434365221356 | Training Accuracy : 99.65055910543131%
# Epoch 96 | Validation Accuracy 88.6570411392405%
# Epoch : [97/200] | Step : [100/313] | Loss : 0.0011820470681414008
# Epoch : [97/200] | Step : [200/313] | Loss : 0.03426612168550491
# Epoch : [97/200] | Step : [300/313] | Loss : 0.005198738072067499
# Epoch : 97 | Loss : 0.013191039965115338 | Training Accuracy : 99.55820686900958%
# Epoch 97 | Validation Accuracy 88.88449367088607%
# Epoch : [98/200] | Step : [100/313] | Loss : 0.021762976422905922
# Epoch : [98/200] | Step : [200/313] | Loss : 0.0014139239210635424
# Epoch : [98/200] | Step : [300/313] | Loss : 0.017848869785666466
# Epoch : 98 | Loss : 0.014902923533342594 | Training Accuracy : 99.4833266773163%
# Epoch 98 | Validation Accuracy 88.39003164556962%
# Epoch : [99/200] | Step : [100/313] | Loss : 0.028228798881173134
# Epoch : [99/200] | Step : [200/313] | Loss : 0.04770783334970474
# Epoch : [99/200] | Step : [300/313] | Loss : 0.014183868654072285
# Epoch : 99 | Loss : 0.014875769102834344 | Training Accuracy : 99.48831869009584%
# Epoch 99 | Validation Accuracy 88.55814873417721%
# Epoch : [100/200] | Step : [100/313] | Loss : 0.027946162968873978
# Epoch : [100/200] | Step : [200/313] | Loss : 0.007287330459803343
# Epoch : [100/200] | Step : [300/313] | Loss : 0.010152232833206654
# Epoch : 100 | Loss : 0.014254115196837547 | Training Accuracy : 99.55820686900958%
# Epoch 100 | Validation Accuracy 87.9746835443038%
# Epoch : [101/200] | Step : [100/313] | Loss : 0.0160975381731987
# Epoch : [101/200] | Step : [200/313] | Loss : 0.008452667854726315
# Epoch : [101/200] | Step : [300/313] | Loss : 0.006879268679767847
# Epoch : 101 | Loss : 0.0150005663577735 | Training Accuracy : 99.48831869009584%
# Epoch 101 | Validation Accuracy 88.94382911392405%
# Epoch : [102/200] | Step : [100/313] | Loss : 0.013265232555568218
# Epoch : [102/200] | Step : [200/313] | Loss : 0.012255730107426643
# Epoch : [102/200] | Step : [300/313] | Loss : 0.00249499105848372
# Epoch : 102 | Loss : 0.012490159036188473 | Training Accuracy : 99.56569488817891%
# Epoch 102 | Validation Accuracy 88.66693037974683%
# Epoch : [103/200] | Step : [100/313] | Loss : 0.006965551059693098
# Epoch : [103/200] | Step : [200/313] | Loss : 0.0073099806904792786
# Epoch : [103/200] | Step : [300/313] | Loss : 0.002389165572822094
# Epoch : 103 | Loss : 0.010311194662151251 | Training Accuracy : 99.61811102236422%
# Epoch 103 | Validation Accuracy 88.80537974683544%
# Epoch : [104/200] | Step : [100/313] | Loss : 0.009404424577951431
# Epoch : [104/200] | Step : [200/313] | Loss : 0.048078954219818115
# Epoch : [104/200] | Step : [300/313] | Loss : 0.0054001640528440475
# Epoch : 104 | Loss : 0.011751213520575619 | Training Accuracy : 99.61062300319489%
# Epoch 104 | Validation Accuracy 88.98338607594937%
# Epoch : [105/200] | Step : [100/313] | Loss : 0.0005120492423884571
# Epoch : [105/200] | Step : [200/313] | Loss : 0.0246178787201643
# Epoch : [105/200] | Step : [300/313] | Loss : 0.0018983226036652923
# Epoch : 105 | Loss : 0.011469438285068474 | Training Accuracy : 99.59065495207668%
# Epoch 105 | Validation Accuracy 88.84493670886076%
# Epoch : [106/200] | Step : [100/313] | Loss : 0.003009901149198413
# Epoch : [106/200] | Step : [200/313] | Loss : 0.009818335063755512
# Epoch : [106/200] | Step : [300/313] | Loss : 0.009455769322812557
# Epoch : 106 | Loss : 0.012021830286953403 | Training Accuracy : 99.60313498402556%
# Epoch 106 | Validation Accuracy 88.54825949367088%
# Epoch : [107/200] | Step : [100/313] | Loss : 0.0012090704403817654
# Epoch : [107/200] | Step : [200/313] | Loss : 0.03360435366630554
# Epoch : [107/200] | Step : [300/313] | Loss : 0.0007493114680983126
# Epoch : 107 | Loss : 0.012472639851362858 | Training Accuracy : 99.57068690095848%
# Epoch 107 | Validation Accuracy 89.16139240506328%
# Saving the model...
# Epoch : [108/200] | Step : [100/313] | Loss : 0.0038841264322400093
# Epoch : [108/200] | Step : [200/313] | Loss : 0.061599235981702805
# Epoch : [108/200] | Step : [300/313] | Loss : 0.0023247981444001198
# Epoch : 108 | Loss : 0.01092250753542224 | Training Accuracy : 99.65555111821087%
# Epoch 108 | Validation Accuracy 88.94382911392405%
# Epoch : [109/200] | Step : [100/313] | Loss : 0.008372089825570583
# Epoch : [109/200] | Step : [200/313] | Loss : 0.001543630613014102
# Epoch : [109/200] | Step : [300/313] | Loss : 0.022512059658765793
# Epoch : 109 | Loss : 0.010964857738598222 | Training Accuracy : 99.62310303514377%
# Epoch 109 | Validation Accuracy 88.3504746835443%
# Epoch : [110/200] | Step : [100/313] | Loss : 0.027035340666770935
# Epoch : [110/200] | Step : [200/313] | Loss : 0.021415844559669495
# Epoch : [110/200] | Step : [300/313] | Loss : 0.004159513395279646
# Epoch : 110 | Loss : 0.011287605755749686 | Training Accuracy : 99.5881589456869%
# Epoch 110 | Validation Accuracy 88.61748417721519%
# Epoch : [111/200] | Step : [100/313] | Loss : 0.027785472571849823
# Epoch : [111/200] | Step : [200/313] | Loss : 0.013572576455771923
# Epoch : [111/200] | Step : [300/313] | Loss : 0.012899371795356274
# Epoch : 111 | Loss : 0.012818881105958892 | Training Accuracy : 99.56569488817891%
# Epoch 111 | Validation Accuracy 89.27017405063292%
# Saving the model...
# Epoch : [112/200] | Step : [100/313] | Loss : 0.011910703033208847
# Epoch : [112/200] | Step : [200/313] | Loss : 0.008647582493722439
# Epoch : [112/200] | Step : [300/313] | Loss : 0.04532378539443016
# Epoch : 112 | Loss : 0.012124700994976907 | Training Accuracy : 99.57318290734824%
# Epoch 112 | Validation Accuracy 88.8251582278481%
# Epoch : [113/200] | Step : [100/313] | Loss : 0.0012786723673343658
# Epoch : [113/200] | Step : [200/313] | Loss : 0.03652503713965416
# Epoch : [113/200] | Step : [300/313] | Loss : 0.006222347728908062
# Epoch : 113 | Loss : 0.009256988939594481 | Training Accuracy : 99.69049520766772%
# Epoch 113 | Validation Accuracy 89.50751582278481%
# Saving the model...
# Epoch : [114/200] | Step : [100/313] | Loss : 0.02241230197250843
# Epoch : [114/200] | Step : [200/313] | Loss : 0.0033417006488889456
# Epoch : [114/200] | Step : [300/313] | Loss : 0.02072414755821228
# Epoch : 114 | Loss : 0.00993412152024212 | Training Accuracy : 99.62809504792332%
# Epoch 114 | Validation Accuracy 88.86471518987342%
# Epoch : [115/200] | Step : [100/313] | Loss : 0.003220429876819253
# Epoch : [115/200] | Step : [200/313] | Loss : 0.00365539756603539
# Epoch : [115/200] | Step : [300/313] | Loss : 0.0015423770528286695
# Epoch : 115 | Loss : 0.010360254919228587 | Training Accuracy : 99.62809504792332%
# Epoch 115 | Validation Accuracy 89.07238924050634%
# Epoch : [116/200] | Step : [100/313] | Loss : 0.0034947667736560106
# Epoch : [116/200] | Step : [200/313] | Loss : 0.0008768689585849643
# Epoch : [116/200] | Step : [300/313] | Loss : 0.03557369112968445
# Epoch : 116 | Loss : 0.009892229081545108 | Training Accuracy : 99.69049520766772%
# Epoch 116 | Validation Accuracy 88.83504746835443%
# Epoch : [117/200] | Step : [100/313] | Loss : 0.014899387955665588
# Epoch : [117/200] | Step : [200/313] | Loss : 0.0007924996898509562
# Epoch : [117/200] | Step : [300/313] | Loss : 0.052603770047426224
# Epoch : 117 | Loss : 0.008178589005747024 | Training Accuracy : 99.73043130990416%
# Epoch 117 | Validation Accuracy 89.38884493670885%
# Epoch : [118/200] | Step : [100/313] | Loss : 0.0029657050035893917
# Epoch : [118/200] | Step : [200/313] | Loss : 0.0020733410492539406
# Epoch : [118/200] | Step : [300/313] | Loss : 0.0007596800569444895
# Epoch : 118 | Loss : 0.010759285183161492 | Training Accuracy : 99.6405750798722%
# Epoch 118 | Validation Accuracy 88.81526898734177%
# Epoch : [119/200] | Step : [100/313] | Loss : 0.0017681173048913479
# Epoch : [119/200] | Step : [200/313] | Loss : 0.0027368359733372927
# Epoch : [119/200] | Step : [300/313] | Loss : 0.0011623105965554714
# Epoch : 119 | Loss : 0.009118085738067655 | Training Accuracy : 99.73043130990416%
# Epoch 119 | Validation Accuracy 89.28995253164557%
# Epoch : [120/200] | Step : [100/313] | Loss : 0.014971960335969925
# Epoch : [120/200] | Step : [200/313] | Loss : 0.0005739835323765874
# Epoch : [120/200] | Step : [300/313] | Loss : 0.003642004681751132
# Epoch : 120 | Loss : 0.007164012458327542 | Training Accuracy : 99.7778554313099%
# Epoch 120 | Validation Accuracy 89.57674050632912%
# Saving the model...
# Epoch : [121/200] | Step : [100/313] | Loss : 0.005789355840533972
# Epoch : [121/200] | Step : [200/313] | Loss : 0.008583514019846916
# Epoch : [121/200] | Step : [300/313] | Loss : 0.0010286924662068486
# Epoch : 121 | Loss : 0.0072178442096047565 | Training Accuracy : 99.78284744408946%
# Epoch 121 | Validation Accuracy 89.41851265822784%
# Epoch : [122/200] | Step : [100/313] | Loss : 0.0006290806340985
# Epoch : [122/200] | Step : [200/313] | Loss : 0.0043388293124735355
# Epoch : [122/200] | Step : [300/313] | Loss : 0.001403429196216166
# Epoch : 122 | Loss : 0.0061049426952488545 | Training Accuracy : 99.83027156549521%
# Epoch 122 | Validation Accuracy 89.44818037974683%
# Epoch : [123/200] | Step : [100/313] | Loss : 0.0063659208826720715
# Epoch : [123/200] | Step : [200/313] | Loss : 0.000888753798790276
# Epoch : [123/200] | Step : [300/313] | Loss : 0.0015898188576102257
# Epoch : 123 | Loss : 0.006072631184630596 | Training Accuracy : 99.8202875399361%
# Epoch 123 | Validation Accuracy 89.6064082278481%
# Saving the model...
# Epoch : [124/200] | Step : [100/313] | Loss : 0.006671522278338671
# Epoch : [124/200] | Step : [200/313] | Loss : 0.002697288990020752
# Epoch : [124/200] | Step : [300/313] | Loss : 0.0011292046401649714
# Epoch : 124 | Loss : 0.004819900008442346 | Training Accuracy : 99.85772763578275%
# Epoch 124 | Validation Accuracy 89.18117088607595%
# Epoch : [125/200] | Step : [100/313] | Loss : 0.0011926689185202122
# Epoch : [125/200] | Step : [200/313] | Loss : 0.0032240869477391243
# Epoch : [125/200] | Step : [300/313] | Loss : 0.01874903216958046
# Epoch : 125 | Loss : 0.00560343281726521 | Training Accuracy : 99.82527955271566%
# Epoch 125 | Validation Accuracy 89.41851265822784%
# Epoch : [126/200] | Step : [100/313] | Loss : 0.0057233283296227455
# Epoch : [126/200] | Step : [200/313] | Loss : 0.0030215431470423937
# Epoch : [126/200] | Step : [300/313] | Loss : 0.018081150949001312
# Epoch : 126 | Loss : 0.0060064835516342036 | Training Accuracy : 99.82527955271566%
# Epoch 126 | Validation Accuracy 89.10205696202532%
# Epoch : [127/200] | Step : [100/313] | Loss : 0.0011457169894129038
# Epoch : [127/200] | Step : [200/313] | Loss : 0.0016236540395766497
# Epoch : [127/200] | Step : [300/313] | Loss : 0.004463902208954096
# Epoch : 127 | Loss : 0.006515813161526582 | Training Accuracy : 99.7778554313099%
# Epoch 127 | Validation Accuracy 89.40862341772153%
# Epoch : [128/200] | Step : [100/313] | Loss : 0.047947924584150314
# Epoch : [128/200] | Step : [200/313] | Loss : 0.018870174884796143
# Epoch : [128/200] | Step : [300/313] | Loss : 0.0009394438820891082
# Epoch : 128 | Loss : 0.00606398855800184 | Training Accuracy : 99.81779153354633%
# Epoch 128 | Validation Accuracy 89.19106012658227%
# Epoch : [129/200] | Step : [100/313] | Loss : 0.0024542701430618763
# Epoch : [129/200] | Step : [200/313] | Loss : 0.03835148364305496
# Epoch : [129/200] | Step : [300/313] | Loss : 0.0029283221811056137
# Epoch : 129 | Loss : 0.008792481983752591 | Training Accuracy : 99.72044728434504%
# Epoch 129 | Validation Accuracy 88.83504746835443%
# Epoch : [130/200] | Step : [100/313] | Loss : 0.004390292800962925
# Epoch : [130/200] | Step : [200/313] | Loss : 0.010223220102488995
# Epoch : [130/200] | Step : [300/313] | Loss : 0.0049074445851147175
# Epoch : 130 | Loss : 0.007814317099421252 | Training Accuracy : 99.74790335463258%
# Epoch 130 | Validation Accuracy 88.81526898734177%
# Epoch : [131/200] | Step : [100/313] | Loss : 0.0029435730539262295
# Epoch : [131/200] | Step : [200/313] | Loss : 0.001437824685126543
# Epoch : [131/200] | Step : [300/313] | Loss : 0.0005752519937232137
# Epoch : 131 | Loss : 0.0059394622628856746 | Training Accuracy : 99.810303514377%
# Epoch 131 | Validation Accuracy 89.20094936708861%
# Epoch : [132/200] | Step : [100/313] | Loss : 0.004756187554448843
# Epoch : [132/200] | Step : [200/313] | Loss : 0.0015713233733549714
# Epoch : [132/200] | Step : [300/313] | Loss : 0.0014352991711348295
# Epoch : 132 | Loss : 0.0079457838617443 | Training Accuracy : 99.76537539936102%
# Epoch 132 | Validation Accuracy 89.03283227848101%
# Epoch : [133/200] | Step : [100/313] | Loss : 0.04869817569851875
# Epoch : [133/200] | Step : [200/313] | Loss : 0.0024766172282397747
# Epoch : [133/200] | Step : [300/313] | Loss : 0.0007083679083734751
# Epoch : 133 | Loss : 0.007194425690456661 | Training Accuracy : 99.7678714057508%
# Epoch 133 | Validation Accuracy 88.88449367088607%
# Epoch : [134/200] | Step : [100/313] | Loss : 0.005165851674973965
# Epoch : [134/200] | Step : [200/313] | Loss : 0.012118601240217686
# Epoch : [134/200] | Step : [300/313] | Loss : 0.00726923905313015
# Epoch : 134 | Loss : 0.005588257688651094 | Training Accuracy : 99.81529552715655%
# Epoch 134 | Validation Accuracy 89.1317246835443%
# Epoch : [135/200] | Step : [100/313] | Loss : 0.01927025243639946
# Epoch : [135/200] | Step : [200/313] | Loss : 0.00032282687607221305
# Epoch : [135/200] | Step : [300/313] | Loss : 0.000993626075796783
# Epoch : 135 | Loss : 0.004937147157052502 | Training Accuracy : 99.84275159744409%
# Epoch 135 | Validation Accuracy 89.63607594936708%
# Saving the model...
# Epoch : [136/200] | Step : [100/313] | Loss : 0.003715139115229249
# Epoch : [136/200] | Step : [200/313] | Loss : 0.0057794214226305485
# Epoch : [136/200] | Step : [300/313] | Loss : 0.000558347615879029
# Epoch : 136 | Loss : 0.0046170563661599735 | Training Accuracy : 99.87020766773162%
# Epoch 136 | Validation Accuracy 89.71518987341773%
# Saving the model...
# Epoch : [137/200] | Step : [100/313] | Loss : 0.002148588187992573
# Epoch : [137/200] | Step : [200/313] | Loss : 0.0004998231306672096
# Epoch : [137/200] | Step : [300/313] | Loss : 0.0008639461593702435
# Epoch : 137 | Loss : 0.004412980562051053 | Training Accuracy : 99.85023961661342%
# Epoch 137 | Validation Accuracy 89.57674050632912%
# Epoch : [138/200] | Step : [100/313] | Loss : 0.005984671879559755
# Epoch : [138/200] | Step : [200/313] | Loss : 0.0013239195104688406
# Epoch : [138/200] | Step : [300/313] | Loss : 0.0013064802624285221
# Epoch : 138 | Loss : 0.006709279286143848 | Training Accuracy : 99.7778554313099%
# Epoch 138 | Validation Accuracy 88.84493670886076%
# Epoch : [139/200] | Step : [100/313] | Loss : 0.0177872646600008
# Epoch : [139/200] | Step : [200/313] | Loss : 0.0046626003459095955
# Epoch : [139/200] | Step : [300/313] | Loss : 0.011336355470120907
# Epoch : 139 | Loss : 0.005154352827272311 | Training Accuracy : 99.83775958466452%
# Epoch 139 | Validation Accuracy 89.31962025316456%
# Epoch : [140/200] | Step : [100/313] | Loss : 0.0007567875436507165
# Epoch : [140/200] | Step : [200/313] | Loss : 0.006644934415817261
# Epoch : [140/200] | Step : [300/313] | Loss : 0.05191584303975105
# Epoch : 140 | Loss : 0.006532490161301854 | Training Accuracy : 99.78534345047923%
# Epoch 140 | Validation Accuracy 88.91416139240506%
# Epoch : [141/200] | Step : [100/313] | Loss : 0.00015664823877159506
# Epoch : [141/200] | Step : [200/313] | Loss : 0.0013173309853300452
# Epoch : [141/200] | Step : [300/313] | Loss : 0.0015161517076194286
# Epoch : 141 | Loss : 0.009356189846794252 | Training Accuracy : 99.6730231629393%
# Epoch 141 | Validation Accuracy 88.77571202531645%
# Epoch : [142/200] | Step : [100/313] | Loss : 0.0013137237401679158
# Epoch : [142/200] | Step : [200/313] | Loss : 0.0008615390979684889
# Epoch : [142/200] | Step : [300/313] | Loss : 0.0008292270358651876
# Epoch : 142 | Loss : 0.005447309300983727 | Training Accuracy : 99.83027156549521%
# Epoch 142 | Validation Accuracy 89.59651898734177%
# Epoch : [143/200] | Step : [100/313] | Loss : 0.011553306132555008
# ...
# Epoch : [154/200] | Step : [200/313] | Loss : 0.0021172789856791496
# Epoch : [154/200] | Step : [300/313] | Loss : 0.00027068579220212996
# Epoch : 154 | Loss : 0.005427244552951373 | Training Accuracy : 99.82527955271566%
# Epoch 154 | Validation Accuracy 89.79430379746836%
# Saving the model...
# Epoch : [155/200] | Step : [100/313] | Loss : 0.00028319904231466353
# Epoch : [155/200] | Step : [200/313] | Loss : 0.007920725271105766
# Epoch : [155/200] | Step : [300/313] | Loss : 0.0037594838067889214
# Epoch : 155 | Loss : 0.00421268192865438 | Training Accuracy : 99.86521565495208%
# Epoch 155 | Validation Accuracy 89.71518987341773%
# Epoch : [156/200] | Step : [100/313] | Loss : 0.0025223593693226576
# Epoch : [156/200] | Step : [200/313] | Loss : 7.073401502566412e-05
# Epoch : [156/200] | Step : [300/313] | Loss : 0.0001693399390205741
# Epoch : 156 | Loss : 0.005608311579931868 | Training Accuracy : 99.82278354632588%
# Epoch 156 | Validation Accuracy 89.54707278481013%
# Epoch : [157/200] | Step : [100/313] | Loss : 0.007316431030631065
# Epoch : [157/200] | Step : [200/313] | Loss : 0.0017761981580406427
# Epoch : [157/200] | Step : [300/313] | Loss : 0.002619838574901223
# Epoch : 157 | Loss : 0.004126191403608105 | Training Accuracy : 99.86771166134186%
# Epoch 157 | Validation Accuracy 89.05261075949366%
# Epoch : [158/200] | Step : [100/313] | Loss : 0.005671418737620115
# Epoch : [158/200] | Step : [200/313] | Loss : 0.00021189378458075225
# Epoch : [158/200] | Step : [300/313] | Loss : 0.014268247410655022
# Epoch : 158 | Loss : 0.006824082525950238 | Training Accuracy : 99.7678714057508%
# Epoch 158 | Validation Accuracy 88.46914556962025%
# Epoch : [159/200] | Step : [100/313] | Loss : 0.004762293770909309
# Epoch : [159/200] | Step : [200/313] | Loss : 0.010156504809856415
# Epoch : [159/200] | Step : [300/313] | Loss : 0.0019622561521828175
# Epoch : 159 | Loss : 0.007768313791280197 | Training Accuracy : 99.75039936102237%
# Epoch 159 | Validation Accuracy 88.98338607594937%
# Epoch : [160/200] | Step : [100/313] | Loss : 0.007708804216235876
# Epoch : [160/200] | Step : [200/313] | Loss : 0.010529587976634502
# Epoch : [160/200] | Step : [300/313] | Loss : 0.0061242771334946156
# Epoch : 160 | Loss : 0.005609811213863909 | Training Accuracy : 99.81279952076677%
# Epoch 160 | Validation Accuracy 89.31962025316456%
# Epoch : [161/200] | Step : [100/313] | Loss : 0.0008456047507934272
# Epoch : [161/200] | Step : [200/313] | Loss : 0.0022981197107583284
# Epoch : [161/200] | Step : [300/313] | Loss : 0.0005462669651024044
# Epoch : 161 | Loss : 0.004840292167733052 | Training Accuracy : 99.84275159744409%
# Epoch 161 | Validation Accuracy 89.66574367088607%
# Epoch : [162/200] | Step : [100/313] | Loss : 0.0013064553495496511
# Epoch : [162/200] | Step : [200/313] | Loss : 0.002112494083121419
# Epoch : [162/200] | Step : [300/313] | Loss : 0.005859291646629572
# Epoch : 162 | Loss : 0.0036117813466297172 | Training Accuracy : 99.89017571884983%
# Epoch 162 | Validation Accuracy 89.57674050632912%
# Epoch : [163/200] | Step : [100/313] | Loss : 0.00032214776729233563
# Epoch : [163/200] | Step : [200/313] | Loss : 0.0015376328956335783
# Epoch : [163/200] | Step : [300/313] | Loss : 0.00018766187713481486
# Epoch : 163 | Loss : 0.004086602058236713 | Training Accuracy : 99.8826876996805%
# Epoch 163 | Validation Accuracy 89.3690664556962%
# Epoch : [164/200] | Step : [100/313] | Loss : 0.0005578638520091772
# Epoch : [164/200] | Step : [200/313] | Loss : 0.0004098402278032154
# Epoch : [164/200] | Step : [300/313] | Loss : 0.00015223165974020958
# Epoch : 164 | Loss : 0.0043266224278538405 | Training Accuracy : 99.85523162939297%
# Epoch 164 | Validation Accuracy 89.52729430379746%
# Epoch : [165/200] | Step : [100/313] | Loss : 0.0002794521569740027
# Epoch : [165/200] | Step : [200/313] | Loss : 0.02220696024596691
# Epoch : [165/200] | Step : [300/313] | Loss : 0.0019551762379705906
# Epoch : 165 | Loss : 0.006286158694764978 | Training Accuracy : 99.79532747603834%
# Epoch 165 | Validation Accuracy 89.04272151898735%
# Epoch : [166/200] | Step : [100/313] | Loss : 0.0006569004617631435
# Epoch : [166/200] | Step : [200/313] | Loss : 0.0014939894899725914
# Epoch : [166/200] | Step : [300/313] | Loss : 0.032629065215587616
# Epoch : 166 | Loss : 0.005191885115383133 | Training Accuracy : 99.83027156549521%
# Epoch 166 | Validation Accuracy 89.49762658227847%
# Epoch : [167/200] | Step : [100/313] | Loss : 0.0023327372036874294
# Epoch : [167/200] | Step : [200/313] | Loss : 0.002445161109790206
# Epoch : [167/200] | Step : [300/313] | Loss : 0.0009262544335797429
# Epoch : 167 | Loss : 0.006454337915446915 | Training Accuracy : 99.7678714057508%
# Epoch 167 | Validation Accuracy 89.57674050632912%
# Epoch : [168/200] | Step : [100/313] | Loss : 0.0033135018311440945
# Epoch : [168/200] | Step : [200/313] | Loss : 0.0009761985274963081
# Epoch : [168/200] | Step : [300/313] | Loss : 0.002220443682745099
# Epoch : 168 | Loss : 0.003943352980157785 | Training Accuracy : 99.87270367412141%
# Epoch 168 | Validation Accuracy 89.33939873417721%
# Epoch : [169/200] | Step : [100/313] | Loss : 0.011392181739211082
# Epoch : [169/200] | Step : [200/313] | Loss : 0.0009115462889894843
# Epoch : [169/200] | Step : [300/313] | Loss : 0.0004704702296294272
# Epoch : 169 | Loss : 0.005593745571963962 | Training Accuracy : 99.8527356230032%
# Epoch 169 | Validation Accuracy 89.9129746835443%
# Saving the model...
# Epoch : [170/200] | Step : [100/313] | Loss : 0.0030353611800819635
# Epoch : [170/200] | Step : [200/313] | Loss : 0.0007224915898405015
# Epoch : [170/200] | Step : [300/313] | Loss : 0.0025711788330227137
# Epoch : 170 | Loss : 0.0034121261144489474 | Training Accuracy : 99.91263977635782%
# Epoch 170 | Validation Accuracy 89.66574367088607%
# Epoch : [171/200] | Step : [100/313] | Loss : 0.006681531202048063
# Epoch : [171/200] | Step : [200/313] | Loss : 0.00024175175349228084
# Epoch : [171/200] | Step : [300/313] | Loss : 0.0006053458200767636
# Epoch : 171 | Loss : 0.0024391052009046493 | Training Accuracy : 99.93759984025559%
# Epoch 171 | Validation Accuracy 90.23931962025317%
# Saving the model...
# Epoch : [172/200] | Step : [100/313] | Loss : 6.950148963369429e-05
# Epoch : [172/200] | Step : [200/313] | Loss : 0.0008050117176026106
# Epoch : [172/200] | Step : [300/313] | Loss : 9.940999007085338e-05
# Epoch : 172 | Loss : 0.0027912295662624854 | Training Accuracy : 99.91263977635782%
# Epoch 172 | Validation Accuracy 90.02175632911393%
# Epoch : [173/200] | Step : [100/313] | Loss : 0.0007045522797852755
# Epoch : [173/200] | Step : [200/313] | Loss : 0.0002697067684493959
# Epoch : [173/200] | Step : [300/313] | Loss : 0.004536101128906012
# Epoch : 173 | Loss : 0.0023398281763091656 | Training Accuracy : 99.93011182108627%
# Epoch 173 | Validation Accuracy 90.0810917721519%
# Epoch : [174/200] | Step : [100/313] | Loss : 0.001800999976694584
# Epoch : [174/200] | Step : [200/313] | Loss : 0.04037286341190338
# Epoch : [174/200] | Step : [300/313] | Loss : 0.0002882673288695514
# Epoch : 174 | Loss : 0.003999063254943726 | Training Accuracy : 99.86521565495208%
# Epoch 174 | Validation Accuracy 89.75474683544303%
# Epoch : [175/200] | Step : [100/313] | Loss : 0.0002911376941483468
# Epoch : [175/200] | Step : [200/313] | Loss : 0.004074621479958296
# Epoch : [175/200] | Step : [300/313] | Loss : 0.0004685891617555171
# Epoch : 175 | Loss : 0.0036373180286458006 | Training Accuracy : 99.8851837060703%
# Epoch 175 | Validation Accuracy 89.65585443037975%
# Epoch : [176/200] | Step : [100/313] | Loss : 0.0009392907959409058
# Epoch : [176/200] | Step : [200/313] | Loss : 0.001639678841456771
# Epoch : [176/200] | Step : [300/313] | Loss : 0.001928813522681594
# Epoch : 176 | Loss : 0.0030474660759765696 | Training Accuracy : 99.92262380191693%
# Epoch 176 | Validation Accuracy 90.0118670886076%
# Epoch : [177/200] | Step : [100/313] | Loss : 0.0011354483431205153
# Epoch : [177/200] | Step : [200/313] | Loss : 0.00045100998249836266
# Epoch : [177/200] | Step : [300/313] | Loss : 0.0024966669734567404
# Epoch : 177 | Loss : 0.002749232811777601 | Training Accuracy : 99.92012779552716%
# Epoch 177 | Validation Accuracy 89.45806962025317%
# Epoch : [178/200] | Step : [100/313] | Loss : 0.01241651177406311
# Epoch : [178/200] | Step : [200/313] | Loss : 0.0006810659542679787
# Epoch : [178/200] | Step : [300/313] | Loss : 0.006360115949064493
# Epoch : 178 | Loss : 0.0036732194573259 | Training Accuracy : 99.89017571884983%
# Epoch 178 | Validation Accuracy 89.18117088607595%
# Epoch : [179/200] | Step : [100/313] | Loss : 5.072107524028979e-05
# Epoch : [179/200] | Step : [200/313] | Loss : 0.00017944096180144697
# Epoch : [179/200] | Step : [300/313] | Loss : 0.00017626574845053256
# Epoch : 179 | Loss : 0.0040286543540328425 | Training Accuracy : 99.87270367412141%
# Epoch 179 | Validation Accuracy 89.37895569620254%
# Epoch : [180/200] | Step : [100/313] | Loss : 0.0011214381083846092
# Epoch : [180/200] | Step : [200/313] | Loss : 0.00025120729696936905
# Epoch : [180/200] | Step : [300/313] | Loss : 0.00037540344055742025
# Epoch : 180 | Loss : 0.002998880519320223 | Training Accuracy : 99.89766373801918%
# Epoch 180 | Validation Accuracy 89.92286392405063%
# Epoch : [181/200] | Step : [100/313] | Loss : 0.00764850340783596
# Epoch : [181/200] | Step : [200/313] | Loss : 0.002033770317211747
# Epoch : [181/200] | Step : [300/313] | Loss : 0.0013351710513234138
# Epoch : 181 | Loss : 0.0025220124042536593 | Training Accuracy : 99.9276158146965%
# Epoch 181 | Validation Accuracy 89.49762658227847%
# Epoch : [182/200] | Step : [100/313] | Loss : 0.0005808428395539522
# Epoch : [182/200] | Step : [200/313] | Loss : 0.006046100985258818
# Epoch : [182/200] | Step : [300/313] | Loss : 0.0008027888834476471
# Epoch : 182 | Loss : 0.0034424632124801964 | Training Accuracy : 99.89766373801918%
# Epoch 182 | Validation Accuracy 89.7745253164557%
# Epoch : [183/200] | Step : [100/313] | Loss : 7.332282257266343e-05
# Epoch : [183/200] | Step : [200/313] | Loss : 0.0005904585705138743
# Epoch : [183/200] | Step : [300/313] | Loss : 0.013442997820675373
# Epoch : 183 | Loss : 0.0034372571226587473 | Training Accuracy : 99.90265575079871%
# Epoch 183 | Validation Accuracy 89.6756329113924%
# Epoch : [184/200] | Step : [100/313] | Loss : 0.0002470651816111058
# Epoch : [184/200] | Step : [200/313] | Loss : 0.0004009508993476629
# Epoch : [184/200] | Step : [300/313] | Loss : 0.0056706639006733894
# Epoch : 184 | Loss : 0.004886144279010822 | Training Accuracy : 99.86022364217251%
# Epoch 184 | Validation Accuracy 89.12183544303798%
# Epoch : [185/200] | Step : [100/313] | Loss : 0.010053395293653011
# Epoch : [185/200] | Step : [200/313] | Loss : 0.0005603401805274189
# Epoch : [185/200] | Step : [300/313] | Loss : 0.0005334832239896059
# Epoch : 185 | Loss : 0.0035235305601473287 | Training Accuracy : 99.8951677316294%
# Epoch 185 | Validation Accuracy 89.50751582278481%
# Epoch : [186/200] | Step : [100/313] | Loss : 0.012994415126740932
# Epoch : [186/200] | Step : [200/313] | Loss : 0.00037269468884915113
# Epoch : [186/200] | Step : [300/313] | Loss : 0.011220035143196583
# Epoch : 186 | Loss : 0.0035344767512606413 | Training Accuracy : 99.89017571884983%
# Epoch 186 | Validation Accuracy 89.41851265822784%
# Epoch : [187/200] | Step : [100/313] | Loss : 0.001360622700303793
# Epoch : [187/200] | Step : [200/313] | Loss : 0.0064661153592169285
# Epoch : [187/200] | Step : [300/313] | Loss : 0.012058713473379612
# Epoch : 187 | Loss : 0.003416292653174531 | Training Accuracy : 99.8826876996805%
# Epoch 187 | Validation Accuracy 89.86352848101265%
# Epoch : [188/200] | Step : [100/313] | Loss : 0.00841960497200489
# Epoch : [188/200] | Step : [200/313] | Loss : 0.0012104292400181293
# Epoch : [188/200] | Step : [300/313] | Loss : 0.00984420720487833
# Epoch : 188 | Loss : 0.0047450887174292555 | Training Accuracy : 99.83526357827476%
# Epoch 188 | Validation Accuracy 89.73496835443038%
# Epoch : [189/200] | Step : [100/313] | Loss : 0.00019551205332390964
# Epoch : [189/200] | Step : [200/313] | Loss : 0.033535487949848175
# Epoch : [189/200] | Step : [300/313] | Loss : 5.461916953208856e-05
# Epoch : 189 | Loss : 0.003634010413241314 | Training Accuracy : 99.86521565495208%
# Epoch 189 | Validation Accuracy 89.76463607594937%
# Epoch : [190/200] | Step : [100/313] | Loss : 0.0014032031176611781
# Epoch : [190/200] | Step : [200/313] | Loss : 0.0019989830907434225
# Epoch : [190/200] | Step : [300/313] | Loss : 0.0005685548530891538
# Epoch : 190 | Loss : 0.004398079420360491 | Training Accuracy : 99.84275159744409%
# Epoch 190 | Validation Accuracy 89.15150316455697%
# Epoch : [191/200] | Step : [100/313] | Loss : 0.011204122565686703
# Epoch : [191/200] | Step : [200/313] | Loss : 0.0008144379826262593
# Epoch : [191/200] | Step : [300/313] | Loss : 0.0004473310546018183
# Epoch : 191 | Loss : 0.0034801725191886154 | Training Accuracy : 99.88767971246007%
# Epoch 191 | Validation Accuracy 89.14161392405063%
# Epoch : [192/200] | Step : [100/313] | Loss : 0.0011819814098998904
# Epoch : [192/200] | Step : [200/313] | Loss : 0.0004545566625893116
# Epoch : [192/200] | Step : [300/313] | Loss : 0.0005090361810289323
# Epoch : 192 | Loss : 0.003538294745918195 | Training Accuracy : 99.89017571884983%
# Epoch 192 | Validation Accuracy 89.65585443037975%
# Epoch : [193/200] | Step : [100/313] | Loss : 0.01136084832251072
# Epoch : [193/200] | Step : [200/313] | Loss : 0.00021480389114003628
# Epoch : [193/200] | Step : [300/313] | Loss : 7.533721509389579e-05
# Epoch : 193 | Loss : 0.003895344051580613 | Training Accuracy : 99.86771166134186%
# Epoch 193 | Validation Accuracy 90.14042721518987%
# Epoch : [194/200] | Step : [100/313] | Loss : 0.0006101506878621876
# Epoch : [194/200] | Step : [200/313] | Loss : 0.0012441620929166675
# Epoch : [194/200] | Step : [300/313] | Loss : 0.006578977219760418
# Epoch : 194 | Loss : 0.0032662221458213316 | Training Accuracy : 99.89017571884983%
# Epoch 194 | Validation Accuracy 89.66574367088607%
# Epoch : [195/200] | Step : [100/313] | Loss : 0.0002075297961710021
# Epoch : [195/200] | Step : [200/313] | Loss : 0.012544662691652775
# Epoch : [195/200] | Step : [300/313] | Loss : 0.000271963479463011
# Epoch : 195 | Loss : 0.002838130486432088 | Training Accuracy : 99.9276158146965%
# Epoch 195 | Validation Accuracy 89.58662974683544%
# Epoch : [196/200] | Step : [100/313] | Loss : 0.0050238147377967834
# Epoch : [196/200] | Step : [200/313] | Loss : 0.0002849720767699182
# Epoch : [196/200] | Step : [300/313] | Loss : 0.002141712000593543
# Epoch : 196 | Loss : 0.006277485557535392 | Training Accuracy : 99.81529552715655%
# Epoch 196 | Validation Accuracy 89.66574367088607%
# Epoch : [197/200] | Step : [100/313] | Loss : 0.044185537844896317
# Epoch : [197/200] | Step : [200/313] | Loss : 0.0002775834873318672
# Epoch : [197/200] | Step : [300/313] | Loss : 0.00041852230788208544
# Epoch : 197 | Loss : 0.004936232053412637 | Training Accuracy : 99.84025559105432%
# Epoch 197 | Validation Accuracy 89.33939873417721%
# Epoch : [198/200] | Step : [100/313] | Loss : 0.0002683396451175213
# Epoch : [198/200] | Step : [200/313] | Loss : 0.00029845768585801125
# Epoch : [198/200] | Step : [300/313] | Loss : 0.0032052292954176664
# Epoch : 198 | Loss : 0.004741327365241631 | Training Accuracy : 99.84524760383387%
# Epoch 198 | Validation Accuracy 89.59651898734177%
# Epoch : [199/200] | Step : [100/313] | Loss : 0.010488624684512615
# Epoch : [199/200] | Step : [200/313] | Loss : 0.0009638374904170632
# Epoch : [199/200] | Step : [300/313] | Loss : 0.0008702334598638117
# Epoch : 199 | Loss : 0.003934750465534668 | Training Accuracy : 99.87769568690096%
# Epoch 199 | Validation Accuracy 89.16139240506328%
# Epoch : [200/200] | Step : [100/313] | Loss : 0.0023475056514143944
# Epoch : [200/200] | Step : [200/313] | Loss : 0.006917386781424284
# Epoch : [200/200] | Step : [300/313] | Loss : 0.0048075891099870205
# Epoch : 200 | Loss : 0.005266224754601475 | Training Accuracy : 99.83775958466452%
# Epoch 200 | Validation Accuracy 90.14042721518987%

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#  pip install pytorch-swats
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorch-swats
#   Downloading pytorch_swats-0.1.0-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from pytorch-swats) (1.11.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->pytorch-swats) (4.1.1)
# Installing collected packages: pytorch-swats
# Successfully installed pytorch-swats-0.1.0

# %%
def test_model(model, test_loader, BEST_MODEL):
   model.load_state_dict(torch.load(BEST_MODEL))

   with torch.no_grad():
     correct_predictions = []
     testing_acc_scores = []
     wrong_predictions = []
     all_targets = []
     all_preds = []

     for images, targets in iter(test_loader):
       images = images.to(device)
       targets = targets.to(device)
       outputs = model(images)
      
       _, preds = torch.max(outputs, 1)
       correct_indicies = (preds == targets).nonzero(as_tuple=True)[0]
       c_images = images[correct_indicies]
       c_targets = targets[correct_indicies]
       c_wrong_preds = preds[correct_indicies]
       testing_acc_scores.append(len(correct_indicies)/targets.shape[0])

       wrong_indicies = (preds != targets).nonzero(as_tuple=True)[0]
       w_images = images[wrong_indicies]
       w_targets = targets[wrong_indicies]
       w_wrong_preds = preds[wrong_indicies]
  
       correct_predictions += zip(c_images, c_targets, c_wrong_preds)
       wrong_predictions += zip(w_images, w_targets, w_wrong_preds)
       all_targets+= zip(targets.cpu().numpy())
       all_preds+= zip(preds.cpu().numpy())
       

     return (sum(testing_acc_scores)/len(testing_acc_scores))*100, correct_predictions, wrong_predictions, all_targets, all_preds

# %%
test_accuracy, correct_predictions, wrong_predictions, all_targets, all_preds = test_model(ResNet34, test_loader, BEST_MODEL='/content/gdrive/MyDrive/optimization/Accuracy_90.23931962025317_batchsize_128_lr_0.001.ckpt' )

print(f'Accuracy of the network on the test dataset: {round(test_accuracy)}')
print(len(correct_predictions))
print(len(wrong_predictions))
print(len(all_preds))
print(len(all_targets))
# Out:
# Accuracy of the network on the test dataset: 89
# 8888
# 1112
# 10000
# 10000
